# %% [markdown]
# ### weighted_average_vote: total weighted average rating
# ---
# ### total_votes: total votes received
# ---
# ### mean_vote: total mean vote
# ---
# ### median_vote: total median vote
# ---
# ### votes_10: number of votes with rating equal to 10
# ---
# ### votes_9: number of votes with rating equal to 9
# ---
# ### votes_8: number of votes with rating equal to 8
# ---
# ### votes_7: number of votes with rating equal to 7
# ---
# ### votes_6: number of votes with rating equal to 6
# ---
# ### votes_5: number of votes with rating equal to 5
# ---
# ### votes_4: number of votes with rating equal to 4
# ---
# ### votes_3: number of votes with rating equal to 3
# ---
# ### votes_2: number of votes with rating equal to 2
# ---
# ### votes_1: number of votes with rating equal to 1
# ---
# ### allgenders_0age_avg_vote: average rating from users with age lower than 18
# ---
# ### allgenders_0age_votes: number of votes from users : age lower than 18
# ---
# ### allgenders_18age_avg_vote: average rating from users with age greater or equal to 18 and lower than 30
# ---
# ### allgenders_18age_votes: number of votes from users with age greater or equal to 18 and lower than 30
# ---
# ### allgenders_30age_avg_vote: average rating from users with age greater or equal to 30 and lower than 45
# ---
# ### allgenders_30age_votes: number of votes from users with age greater or equal to 30 and lower than 45
# ---
# ### allgenders_45age_avg_vote: average rating from users with age greater or equal to 45
# ---
# ### allgenders_45age_votes: number of votes from users with age greater or equal to 45
# ---
# ### males_allages_avg_vote: average rating from all male users with demographic data available (all ages)
# ---
# ### males_allages_votes: number of votes from all male users with demographic data available (all ages)
# ---
# ### males_0age_avg_vote: average rating from male users with age lower than 18
# ---
# ### males_0age_votes: number of votes from male users with age lower than 18
# ---
# ### males_18age_avg_vote: average rating from male users with age greater or equal to 18 and lower than 30
# ---
# ### males_18age_votes: number of votes from male users with age greater or equal to 18 and lower than 30
# ---
# ### males_30age_avg_vote: average rating from male users with age greater or equal to 30 and lower than 45
# ---
# ### males_30age_votes: number of votes from male users with age greater or equal to 30 and lower than 45
# ---
# ### males_45age_avg_vote: average rating from male users with age greater or equal to 45
# ---
# ### males_45age_votes: number of votes from male users with age greater or equal to 45
# ---
# ### females_allages_avg_vote: average rating from all female users with demographic data available (all ages)
# ---
# ### females_allages_votes: number of votes from all female users with demographic data available (all ages)
# ---
# ### females_0age_avg_vote: average rating from female users with age lower than 18
# ---
# ### females_0age_votes: number of votes from female users with age lower than 18
# ---
# ### females_18age_avg_vote: average rating from female users with age greater or equal to 18 and lower than 30
# ---
# ### females_18age_votes: number of votes from female users with age greater or equal to 18 and lower than 30
# ---
# ### females_30age_avg_vote: average rating from female users with age greater or equal to 30 and lower than 45
# ---
# ### females_30age_votes: number of votes from female users with age greater or equal to 30 and lower than 45
# ---
# ### females_45age_avg_vote: average rating from male users with age greater or equal to 45
# ---
# ### females_45age_votes: number of votes from male users with age greater or equal to 45
# ---
# ### top1000_voters_rating: average rating from top 1000 voters
# ---
# ### top1000_voters_votes: number of votes from top 1000 voters
# ---
# ### us_voters_rating: average rating from US voters
# ---
# ### us_voters_votes: number of votes from US voters
# ---
# ### non_us_voters_rating: average rating from non-US voters
# ---
# ### non_us_voters_votes: number of votes from non-US voters

# %% [markdown]
# ### imdb_title_id: ID do título no IMDb
# ---
# ### title: nome do título
# ---
# ### original_title: nome do título original
# ---
# ### year: Ano de lançamento
# ---
# ### date_published: data de lançamento
# ---
# ### genre: gênero de filme
# ---
# ### duration: duração (em minutos)
# ---
# ### country: país de produção
# ---
# ### language: linguagem do filme
# ---
# ### director: nome do diretor
# ---
# ### writer: nome do escritor
# ---
# ### production_company: companhia de produção
# ---
# ### actors: nomes de atores
# ---
# ### description: descrição do enredo
# ---
# ### avg_vote: voto médio
# ---
# ### votes: número de votos recebidos
# ---
# ### budget: despesas
# ---
# ### usa_gross_income: Renda bruta dos EUA
# ---
# ### worlwide_gross_income: renda bruta mundial
# ---
# ### metascore: classificação metascore
# ---
# ### reviews_from_users: número de comentários de usuários
# ---
# ### reviews_from_critics: número de comentários dos críticos

# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
df_movie = pd.read_csv(r'Arquivos/IMDb movies.csv')
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85855 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85855 non-null  object
#  1   title                  85855 non-null  object
#  2   original_title         85855 non-null  object
#  3   year                   85855 non-null  object
#  4   date_published         85855 non-null  object
#  5   genre                  85855 non-null  object
#  6   duration               85855 non-null  int64
#  7   country                85791 non-null  object
#  8   language               85022 non-null  object
#  9   director               85768 non-null  object
#  10  writer                 84283 non-null  object
#  11  production_company     81400 non-null  object
#  12  actors                 85786 non-null  object
#  13  description            83740 non-null  object
# ...

# %%
df_movie.shape
# Out:
# (85855, 22)

# %%
df_movie.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Análises

# %%
df_movie.isnull().sum()
# Out:
# imdb_title_id                0
# title                        0
# original_title               0
# year                         0
# date_published               0
# genre                        0
# duration                     0
# country                     64
# language                   833
# director                    87
# writer                    1572
# production_company        4455
# actors                      69
# description               2115
# avg_vote                     0
# votes                        0
# budget                   62145
# usa_gross_income         70529
# worlwide_gross_income    54839
# metascore                72550
# reviews_from_users        7597
# reviews_from_critics     11797
# dtype: int64

# %%
df_movie['language'].value_counts()
# Out:
# English                                                     35939
# French                                                       3903
# Spanish                                                      2831
# Japanese                                                     2826
# Italian                                                      2731
#                                                             ...
# English, Spanish, Icelandic                                     1
# French, Arabic, English, Italian                                1
# Italian, German, Latin, English, Spanish, Polish, French        1
# Korean, Russian, English                                        1
# Filipino, Tagalog, Japanese, English                            1
# Name: language, Length: 4377, dtype: int64

# %%
df_movie[df_movie['title'] != df_movie['original_title']]
# Out:
#       imdb_title_id                                          title  \
# 12        tt0003014                       Il calvario di una madre
# 17        tt0003167                                 Amore di madre
# 18        tt0003419                           Lo studente di Praga
# 38        tt0004681                         La madonnina del porto
# 47        tt0004972                         Nascita di una nazione
# ...             ...                                            ...
# 85790     tt9828918                                     #IoSonoQui
# 85805     tt9850064                            Children of the Sea
# 85807     tt9855978          Dreambuilders - La fabbrica dei sogni
# 85811     tt9860728  Falling Inn Love - Ristrutturazione con amore
# 85842     tt9900060          Lupin III: La menzogna di Fujiko Mine
#
#                             original_title  year date_published  \
# 12                           Ingeborg Holm  1913     1915-10-18
# ...

# %%
df_movie[df_movie['duration'] == df_movie['duration'].max()]
# Out:
#       imdb_title_id    title original_title  year date_published  \
# 85057     tt9047474  La flor        La flor  2016     2018-09-21
#
#                          genre  duration    country  \
# 85057  Drama, Fantasy, Musical       808  Argentina
#
#                                                 language        director  \
# 85057  Catalan, Spanish, French, English, Russian, Ge...  Mariano Llinás
#
#                writer production_company  \
# 85057  Mariano Llinás    El Pampero Cine
#
#                                                   actors  \
# 85057  Elisa Carricajo, Valeria Correa, Pilar Gamboa,...
#
#                                              description  avg_vote  votes  \
# 85057  A film in six episodes, connected by the same ...       7.7    473
#
#       budget usa_gross_income worlwide_gross_income  metascore  \
# 85057    NaN           $ 4032                $ 4032       77.0
#
#        reviews_from_users  reviews_from_critics
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Tratamentos

# %% [markdown]
# ### Date

# %%
df_movie[['year', 'date_published']] = df_movie[['year', 'date_published']].astype(str)
df_movie['year'] = df_movie['year'].apply(lambda x: x.replace("TV Movie ", ""))
df_movie['year'] = df_movie['year'].apply(lambda x: x.replace("'", ""))

df_movie['year'] = pd.to_numeric(df_movie['year'])

# %%
df_movie['date_published'] = df_movie['date_published'].apply(lambda x: x.replace("TV Movie ", ""))
df_movie['date_published'] = pd.to_datetime(df_movie['date_published'])

# %% [markdown]
# ### País

# %%
df_movie.drop(df_movie[df_movie['country'].isnull() == True].index, inplace=True)

# %% [markdown]
# ### Idioma

# %% [markdown]
# #### A fazer

# %%
df_movie[(~df_movie['country'].str.contains(', ')) & 
         (df_movie['language'].isnull() == True)]
# Out:
#       imdb_title_id                     title          original_title  year  \
# 8         tt0002452     Independenta Romaniei   Independenta Romaniei  1912
# 12        tt0003014  Il calvario di una madre           Ingeborg Holm  1913
# 21        tt0003637             Assunta Spina           Assunta Spina  1915
# 41        tt0004743         Uncle Tom's Cabin       Uncle Tom's Cabin  1914
# 53        tt0005529               Hævnens Nat             Hævnens Nat  1916
# ...             ...                       ...                     ...   ...
# 85653     tt9652888    Along Came the Devil 2  Along Came the Devil 2  2019
# 85781     tt9817300                 15 August               15 August  2019
# 85794     tt9838372            Fei fen shu nü          Fei fen shu nü  2019
# 85829     tt9887520            Season of Love          Season of Love  2019
# 85834     tt9894098                    Sathru                  Sathru  2019
#
# ...

# %%
df_movie[df_movie['country'].index == 83234]
# Out:
#       imdb_title_id    title original_title  year date_published  \
# 83234     tt7791188  The Bra        The Bra  2018     2019-11-14
#
#                genre  duration              country language     director  \
# 83234  Comedy, Drama        90  Germany, Azerbaijan     None  Veit Helmer
#
#                               writer          production_company  \
# 83234  Leonie Geisinger, Veit Helmer  Veit Helmer Filmproduktion
#
#                                                   actors  \
# 83234  Predrag 'Miki' Manojlovic, Denis Lavant, Paz V...
#
#                                              description  avg_vote  votes  \
# 83234  Train driver Nurlan is heading to Baku for the...       6.7    402
#
#       budget usa_gross_income worlwide_gross_income  metascore  \
# 83234    NaN              NaN               $ 38291        NaN
#
#        reviews_from_users  reviews_from_critics
# 83234                 6.0                  21.0

# %% [markdown]
# ---

# %%
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85791 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          85791 non-null  object
#  1   title                  85791 non-null  object
#  2   original_title         85791 non-null  object
#  3   year                   85791 non-null  int64
#  4   date_published         85791 non-null  datetime64[ns]
#  5   genre                  85791 non-null  object
#  6   duration               85791 non-null  int64
#  7   country                85791 non-null  object
#  8   language               84983 non-null  object
#  9   director               85711 non-null  object
#  10  writer                 84232 non-null  object
#  11  production_company     81354 non-null  object
#  12  actors                 85725 non-null  object
#  13  description            83676 non-null  object
# ...

# %%
df_movie.drop(df_movie[df_movie['director'].isnull() == True].index, inplace=True)
df_movie.drop(df_movie[df_movie['production_company'].isnull() == True].index, inplace=True)
df_movie.drop(df_movie[df_movie['writer'].isnull() == True].index, inplace=True)
df_movie.drop(df_movie[df_movie['actors'].isnull() == True].index, inplace=True)

# %%
df_movie.isnull().sum()
# Out:
# imdb_title_id                0
# title                        0
# original_title               0
# year                         0
# date_published               0
# genre                        0
# duration                     0
# country                      0
# language                   724
# director                     0
# writer                       0
# production_company           0
# actors                       0
# description               1818
# avg_vote                     0
# votes                        0
# budget                   57254
# usa_gross_income         65061
# worlwide_gross_income    50400
# metascore                67010
# reviews_from_users        6344
# reviews_from_critics      9677
# dtype: int64

# %%
# imdb_title_id                0
# title                        0
# original_title               0
# year                         0
# date_published               0
# genre                        0
# duration                     0
# country                      0
# director                     0
# actors                      55
# avg_vote                     0
# votes                        0

# production_company        4416

# writer                    1516

# %%
df_movie['description'].fillna(' ', inplace=True)

# %%
df_movie.isnull().sum()
# Out:
# imdb_title_id                0
# title                        0
# original_title               0
# year                         0
# date_published               0
# genre                        0
# duration                     0
# country                      0
# language                   724
# director                     0
# writer                       0
# production_company           0
# actors                       0
# description                  0
# avg_vote                     0
# votes                        0
# budget                   57254
# usa_gross_income         65061
# worlwide_gross_income    50400
# metascore                67010
# reviews_from_users        6344
# reviews_from_critics      9677
# dtype: int64

# %%
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80162 entries, 0 to 85854
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_title_id          80162 non-null  object
#  1   title                  80162 non-null  object
#  2   original_title         80162 non-null  object
#  3   year                   80162 non-null  int64
#  4   date_published         80162 non-null  datetime64[ns]
#  5   genre                  80162 non-null  object
#  6   duration               80162 non-null  int64
#  7   country                80162 non-null  object
#  8   language               79438 non-null  object
#  9   director               80162 non-null  object
#  10  writer                 80162 non-null  object
#  11  production_company     80162 non-null  object
#  12  actors                 80162 non-null  object
#  13  description            80162 non-null  object
# ...

# %%
df_movie.drop(columns=['reviews_from_critics', 'reviews_from_users', 'metascore', 'worlwide_gross_income', 
                       'usa_gross_income', 'budget', 'language', 'title'], inplace=True)

# %%
df_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80162 entries, 0 to 85854
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   imdb_title_id       80162 non-null  object
#  1   original_title      80162 non-null  object
#  2   year                80162 non-null  int64
#  3   date_published      80162 non-null  datetime64[ns]
#  4   genre               80162 non-null  object
#  5   duration            80162 non-null  int64
#  6   country             80162 non-null  object
#  7   director            80162 non-null  object
#  8   writer              80162 non-null  object
#  9   production_company  80162 non-null  object
#  10  actors              80162 non-null  object
#  11  description         80162 non-null  object
#  12  avg_vote            80162 non-null  float64
#  13  votes               80162 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(9)
# ...

# %%
df_movie.to_csv('Arquivos/movie_trated.csv', index=None)
